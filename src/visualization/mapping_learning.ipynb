# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx

# set font
plt.rcParams.update({'font.size': 14})
# set colors
tab20 = cm = plt.get_cmap('tab20') 
cNorm  = colors.Normalize(vmin=0, vmax=10)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=tab20)


#######################
### Learning Curves ###
#######################
transformer = [{'train/loss': 6.0386, 'train/global_step': 50}, {'train/loss': 5.0644, 'train/global_step': 100}, {'train/loss': 4.3561, 'train/global_step': 150}, {'train/loss': 4.0119, 'train/global_step': 200}, {'train/loss': 3.8413, 'train/global_step': 250}, {'train/loss': 3.6747, 'train/global_step': 300}, {'train/loss': 3.5627, 'train/global_step': 350}, {'train/loss': 3.4733, 'train/global_step': 400}, {'train/loss': 3.4117, 'train/global_step': 450}, {'train/loss': 3.3453, 'train/global_step': 500}, {'train/loss': 3.2668, 'train/global_step': 550}, {'train/loss': 3.2372, 'train/global_step': 600}, {'train/loss': 3.1887, 'train/global_step': 650}, {'train/loss': 3.1469, 'train/global_step': 700}, {'train/loss': 3.1046, 'train/global_step': 750}, {'train/loss': 3.0792, 'train/global_step': 800}, {'train/loss': 3.0422, 'train/global_step': 850}, {'train/loss': 3.0323, 'train/global_step': 900}, {'train/loss': 2.9992, 'train/global_step': 950}, {'train/loss': 2.9808, 'train/global_step': 1000}, {'train/loss': 2.9573, 'train/global_step': 1050}, {'train/loss': 2.929, 'train/global_step': 1100}, {'train/loss': 2.9298, 'train/global_step': 1150}, {'train/loss': 2.9019, 'train/global_step': 1200}, {'train/loss': 2.8646, 'train/global_step': 1250}, {'train/loss': 2.852, 'train/global_step': 1300}, {'train/loss': 2.8602, 'train/global_step': 1350}, {'train/loss': 2.8603, 'train/global_step': 1400}, {'train/loss': 2.833, 'train/global_step': 1450}, {'train/loss': 2.8123, 'train/global_step': 1500}, {'train/loss': 2.788, 'train/global_step': 1550}, {'train/loss': 2.7826, 'train/global_step': 1600}, {'train/loss': 2.7979, 'train/global_step': 1650}, {'train/loss': 2.7676, 'train/global_step': 1700}, {'train/loss': 2.7589, 'train/global_step': 1750}, {'train/loss': 2.751, 'train/global_step': 1800}, {'train/loss': 2.7594, 'train/global_step': 1850}, {'train/loss': 2.71, 'train/global_step': 1900}, {'train/loss': 2.6991, 'train/global_step': 1950}, {'train/loss': 2.7157, 'train/global_step': 2000}, {'train/loss': 2.6806, 'train/global_step': 2050}, {'train/loss': 2.6826, 'train/global_step': 2100}, {'train/loss': 2.6862, 'train/global_step': 2150}, {'train/loss': 2.6814, 'train/global_step': 2200}, {'train/loss': 2.6636, 'train/global_step': 2250}, {'train/loss': 2.6786, 'train/global_step': 2300}] #, {'train/loss': 2.6018, 'train/global_step': 2350}]
# data_lists = [transformer, mlp4_128, mlp3_128, mlp2_512, mlp2_384, mlp2_128]
# labels = ["Tranformer 4x128 ", "MLP 4x128", "MLP 3x128", "MLP 2x512", "MLP 2x384", "MLP 2x128"]
models = [mlp2_128, mlp3_128, mlp4_128,  transformer, mlp2_384, mlp2_512]
labels = ["MLP 2x128", "MLP 3x128", "MLP 4x128", "Tranformer 4x128 ", "MLP 2x384", "MLP 2x512"]


# Plot each list on the same graph
plt.figure(figsize=(10, 6))

for i, data in enumerate(models):
    x_values = [entry['train/global_step'] for entry in data]
    y_values = [entry['train/loss'] for entry in data]
    plt.plot(x_values, y_values, label=labels[i], color=scalarMap.to_rgba( i ))  # label each line

# Set labels and title
plt.xlabel('Step')
plt.ylabel('Loss')
# plt.title('Training Loss vs Global Step')
plt.legend() 
plt.grid(True)
# plt.show()
plt.savefig(f'mapping_learning_curves.pdf', bbox_inches='tight')

# %%
########################
### Size vs Accuracy ###
########################
transformer = [{"Params": 2.18, "Zero-shot": 39.92, "FT": 53.18}]
mlp4_128 = [{"Params": 1.22, "Zero-shot": 41.56, "FT": 54.20}]
mlp3_128 = [{"Params": 1.18, "Zero-shot": 42.72, "FT": 52.71}]
mlp2_512 = [{"Params": 4.98, "Zero-shot": 41.58, "FT": 53.50}]
mlp2_384 = [{"Params": 3.74, "Zero-shot": 41.54, "FT": 53.34}]
# mlp2_256 = [{"Params": 2.36, "Zero-shot": , "FT": }]
mlp2_128 = [{"Params": 1.15, "Zero-shot": 38.21, "FT": 51.30}]

# models = [transformer, mlp4_128, mlp3_128, mlp2_512, mlp2_384, mlp2_128]
# labels = ["Tranformer 4x128 ", "MLP 4x128", "MLP 3x128", "MLP 2x512", "MLP 2x384", "MLP 2x128"]
models = [mlp2_128, mlp3_128, mlp4_128,  transformer, mlp2_384, mlp2_512]
labels = ["MLP 2x128", "MLP 3x128", "MLP 4x128", "Tranformer 4x128 ", "MLP 2x384", "MLP 2x512"]

# Extract data for plotting
params = [model[0]["Params"] for model in models]
zero_shot_accuracies = [model[0]["Zero-shot"] for model in models]
ft_accuracies = [model[0]["FT"] for model in models]

# # Create scatter plot
plt.figure(figsize=(10, 6))
# plt.scatter(params, zero_shot_accuracies, color='blue', label='Zero-shot', marker='o')
# plt.scatter(params, ft_accuracies, color='red', label='FT', marker='x')
for i, data in enumerate(models):
    x_values = [entry['Params'] for entry in data]
    y_values0 = [entry['Zero-shot'] for entry in data]
    y_values1 = [entry['FT'] for entry in data]
    colorVal = scalarMap.to_rgba( i )
    plt.scatter(x_values, y_values0, label=labels[i], marker='o', color=colorVal)
    plt.scatter(x_values, y_values1, marker='x', color=colorVal)



# Labeling axes and title
plt.xlabel('N. Parameters (Millions)')
plt.ylabel('Accuracy (%)')
# plt.title('Model Accuracy vs. Parameters')
plt.legend()
plt.grid(True)
# plt.show()
plt.savefig(f'mapping_accuracy_medqa.pdf', bbox_inches='tight')
